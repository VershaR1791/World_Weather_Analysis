# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of random longitude and latitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.00, high = 180.00, size = 2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 715

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=411052a4625684b086d27e306d6abdd8

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | belyy yar
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 1 | longyearbyen
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | mocuba
# Processing Record 11 of Set 1 | cayenne
# Processing Record 12 of Set 1 | ribeira grande
# Processing Record 13 of Set 1 | samarai
# Processing Record 14 of Set 1 | huarmey
# Processing Record 15 of Set 1 | cap malheureux
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | guerrero negro
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | opunake
# Processing Record 23 of Set 1 | atherton
# Processing Record 24 of Set 1 | mehamn
# Processing Record 25 of Set 1 | banyo
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | itarema
# Processing Record 28 of Set 1 | aklavik
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | tilichiki
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | salalah
# Processing Record 33 of Set 1 | chengde
# Processing Record 34 of Set 1 | jalu
# Processing Record 35 of Set 1 | lorengau
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | provideniya
# Processing Record 38 of Set 1 | te anau
# Processing Record 39 of Set 1 | vanimo
# Processing Record 40 of Set 1 | ketchikan
# Processing Record 41 of Set 1 | kodiak
# Processing Record 42 of Set 1 | ilovlya
# Processing Record 43 of Set 1 | hailar
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | upernavik
# Processing Record 46 of Set 1 | bandraboua
# Processing Record 47 of Set 1 | leshukonskoye
# Processing Record 48 of Set 1 | fortuna
# Processing Record 49 of Set 1 | ankang
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | portland
# Processing Record 2 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | buala
# Processing Record 5 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | zhangjiakou
# Processing Record 8 of Set 2 | leningradskiy
# Processing Record 9 of Set 2 | borujan
# City not found. Skipping...
# Processing Record 10 of Set 2 | halifax
# Processing Record 11 of Set 2 | san vicente
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | lebu
# Processing Record 15 of Set 2 | srednekolymsk
# Processing Record 16 of Set 2 | ancud
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | ormara
# Processing Record 19 of Set 2 | marawi
# Processing Record 20 of Set 2 | deputatskiy
# Processing Record 21 of Set 2 | nuristan
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | saint george
# Processing Record 24 of Set 2 | maumere
# Processing Record 25 of Set 2 | beloha
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | egvekinot
# Processing Record 28 of Set 2 | bambanglipuro
# Processing Record 29 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 2 | san cristobal
# Processing Record 31 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 2 | airai
# Processing Record 33 of Set 2 | bredasdorp
# Processing Record 34 of Set 2 | coffs harbour
# Processing Record 35 of Set 2 | svencionys
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | shingu
# Processing Record 38 of Set 2 | walvis bay
# Processing Record 39 of Set 2 | nikolskoye
# Processing Record 40 of Set 2 | vao
# Processing Record 41 of Set 2 | itaituba
# Processing Record 42 of Set 2 | lompoc
# Processing Record 43 of Set 2 | vila velha
# Processing Record 44 of Set 2 | kavieng
# Processing Record 45 of Set 2 | usinsk
# Processing Record 46 of Set 2 | uige
# Processing Record 47 of Set 2 | filadelfia
# Processing Record 48 of Set 2 | poum
# Processing Record 49 of Set 2 | ostrovnoy
# Processing Record 50 of Set 2 | pombas
# Processing Record 1 of Set 3 | xiuyan
# Processing Record 2 of Set 3 | college
# Processing Record 3 of Set 3 | namatanai
# Processing Record 4 of Set 3 | asau
# Processing Record 5 of Set 3 | simao
# Processing Record 6 of Set 3 | nalut
# Processing Record 7 of Set 3 | topeka
# Processing Record 8 of Set 3 | saint-philippe
# Processing Record 9 of Set 3 | kaitangata
# Processing Record 10 of Set 3 | barma
# Processing Record 11 of Set 3 | kargil
# Processing Record 12 of Set 3 | paamiut
# Processing Record 13 of Set 3 | shitanjing
# Processing Record 14 of Set 3 | kruisfontein
# Processing Record 15 of Set 3 | severnyy
# Processing Record 16 of Set 3 | bluff
# Processing Record 17 of Set 3 | jacqueville
# Processing Record 18 of Set 3 | comodoro rivadavia
# Processing Record 19 of Set 3 | ponta do sol
# Processing Record 20 of Set 3 | isangel
# Processing Record 21 of Set 3 | muisne
# Processing Record 22 of Set 3 | torbay
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | cherskiy
# Processing Record 25 of Set 3 | kudat
# Processing Record 26 of Set 3 | lokosovo
# Processing Record 27 of Set 3 | grindavik
# Processing Record 28 of Set 3 | iguape
# Processing Record 29 of Set 3 | port elizabeth
# Processing Record 30 of Set 3 | pathein
# Processing Record 31 of Set 3 | masuguru
# Processing Record 32 of Set 3 | saint-augustin
# Processing Record 33 of Set 3 | pasni
# Processing Record 34 of Set 3 | santa rosa
# Processing Record 35 of Set 3 | katsuura
# Processing Record 36 of Set 3 | kortkeros
# Processing Record 37 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 3 | severo-kurilsk
# Processing Record 39 of Set 3 | butaritari
# Processing Record 40 of Set 3 | kahului
# Processing Record 41 of Set 3 | narsaq
# Processing Record 42 of Set 3 | nanzhou
# Processing Record 43 of Set 3 | chokurdakh
# Processing Record 44 of Set 3 | altamont
# Processing Record 45 of Set 3 | morris
# Processing Record 46 of Set 3 | tuatapere
# Processing Record 47 of Set 3 | mount isa
# Processing Record 48 of Set 3 | dikson
# Processing Record 49 of Set 3 | yellowknife
# Processing Record 50 of Set 3 | esperance
# Processing Record 1 of Set 4 | dingle
# Processing Record 2 of Set 4 | hobart
# Processing Record 3 of Set 4 | tual
# Processing Record 4 of Set 4 | pitimbu
# Processing Record 5 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 4 | geraldton
# Processing Record 8 of Set 4 | bonthe
# Processing Record 9 of Set 4 | huilong
# Processing Record 10 of Set 4 | arrifes
# Processing Record 11 of Set 4 | kavaratti
# Processing Record 12 of Set 4 | alofi
# Processing Record 13 of Set 4 | kunming
# Processing Record 14 of Set 4 | fengrun
# Processing Record 15 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 16 of Set 4 | north bend
# Processing Record 17 of Set 4 | zambrano
# Processing Record 18 of Set 4 | karratha
# Processing Record 19 of Set 4 | rio pomba
# Processing Record 20 of Set 4 | shostka
# Processing Record 21 of Set 4 | seka
# Processing Record 22 of Set 4 | mwinilunga
# Processing Record 23 of Set 4 | victoria
# Processing Record 24 of Set 4 | gubkinskiy
# Processing Record 25 of Set 4 | rehoboth
# Processing Record 26 of Set 4 | chapais
# Processing Record 27 of Set 4 | iqaluit
# Processing Record 28 of Set 4 | cotonou
# Processing Record 29 of Set 4 | manicore
# Processing Record 30 of Set 4 | uwayl
# City not found. Skipping...
# Processing Record 31 of Set 4 | scarborough
# Processing Record 32 of Set 4 | makakilo city
# Processing Record 33 of Set 4 | ixtapa
# Processing Record 34 of Set 4 | ilulissat
# Processing Record 35 of Set 4 | kununurra
# Processing Record 36 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 37 of Set 4 | waipawa
# Processing Record 38 of Set 4 | mianyang
# Processing Record 39 of Set 4 | bonavista
# Processing Record 40 of Set 4 | cidreira
# Processing Record 41 of Set 4 | coquimbo
# Processing Record 42 of Set 4 | chau doc
# Processing Record 43 of Set 4 | udalguri
# Processing Record 44 of Set 4 | znamenskoye
# Processing Record 45 of Set 4 | saldanha
# Processing Record 46 of Set 4 | zeya
# Processing Record 47 of Set 4 | bambous virieux
# Processing Record 48 of Set 4 | kaeo
# Processing Record 49 of Set 4 | bengkulu
# Processing Record 50 of Set 4 | jamestown
# Processing Record 1 of Set 5 | middle island
# Processing Record 2 of Set 5 | ekibastuz
# Processing Record 3 of Set 5 | thurso
# Processing Record 4 of Set 5 | namibe
# Processing Record 5 of Set 5 | miri
# Processing Record 6 of Set 5 | puerto escondido
# Processing Record 7 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 5 | arraial do cabo
# Processing Record 9 of Set 5 | kaitong
# Processing Record 10 of Set 5 | chingirlau
# Processing Record 11 of Set 5 | kremenki
# Processing Record 12 of Set 5 | olafsvik
# Processing Record 13 of Set 5 | newport
# Processing Record 14 of Set 5 | cairns
# Processing Record 15 of Set 5 | feni
# Processing Record 16 of Set 5 | kananga
# Processing Record 17 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 18 of Set 5 | luderitz
# Processing Record 19 of Set 5 | raudeberg
# Processing Record 20 of Set 5 | chuy
# Processing Record 21 of Set 5 | novo aripuana
# Processing Record 22 of Set 5 | jumla
# Processing Record 23 of Set 5 | tasiilaq
# Processing Record 24 of Set 5 | zyryanka
# Processing Record 25 of Set 5 | santiago del estero
# Processing Record 26 of Set 5 | tres arroyos
# Processing Record 27 of Set 5 | sioux lookout
# Processing Record 28 of Set 5 | vardo
# Processing Record 29 of Set 5 | praia
# Processing Record 30 of Set 5 | pringsewu
# Processing Record 31 of Set 5 | champerico
# Processing Record 32 of Set 5 | naryan-mar
# Processing Record 33 of Set 5 | bodden town
# Processing Record 34 of Set 5 | husavik
# Processing Record 35 of Set 5 | hounde
# Processing Record 36 of Set 5 | batemans bay
# Processing Record 37 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 5 | yazoo city
# Processing Record 39 of Set 5 | itoman
# Processing Record 40 of Set 5 | georgetown
# Processing Record 41 of Set 5 | grand gaube
# Processing Record 42 of Set 5 | pisco
# Processing Record 43 of Set 5 | hit
# Processing Record 44 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 5 | malanje
# Processing Record 46 of Set 5 | dunmore east
# Processing Record 47 of Set 5 | garmsar
# Processing Record 48 of Set 5 | pevek
# Processing Record 49 of Set 5 | zhumadian
# Processing Record 50 of Set 5 | kanniyakumari
# Processing Record 1 of Set 6 | talnakh
# Processing Record 2 of Set 6 | moranbah
# Processing Record 3 of Set 6 | atar
# Processing Record 4 of Set 6 | souillac
# Processing Record 5 of Set 6 | lenggries
# Processing Record 6 of Set 6 | mouzakion
# City not found. Skipping...
# Processing Record 7 of Set 6 | krasnokamensk
# Processing Record 8 of Set 6 | andenes
# Processing Record 9 of Set 6 | cabo san lucas
# Processing Record 10 of Set 6 | thompson
# Processing Record 11 of Set 6 | saint andrews
# Processing Record 12 of Set 6 | kirakira
# Processing Record 13 of Set 6 | nanortalik
# Processing Record 14 of Set 6 | port-gentil
# Processing Record 15 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 6 | hofn
# Processing Record 17 of Set 6 | jinxiang
# Processing Record 18 of Set 6 | lubao
# Processing Record 19 of Set 6 | hobyo
# Processing Record 20 of Set 6 | ugoofaaru
# Processing Record 21 of Set 6 | bethel
# Processing Record 22 of Set 6 | abapo
# Processing Record 23 of Set 6 | nantucket
# Processing Record 24 of Set 6 | puerto ayora
# Processing Record 25 of Set 6 | tezu
# Processing Record 26 of Set 6 | shelburne
# Processing Record 27 of Set 6 | topolobampo
# Processing Record 28 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 6 | derzhavinsk
# Processing Record 30 of Set 6 | jatiroto
# Processing Record 31 of Set 6 | bonfim
# Processing Record 32 of Set 6 | homer
# Processing Record 33 of Set 6 | at-bashi
# Processing Record 34 of Set 6 | we
# City not found. Skipping...
# Processing Record 35 of Set 6 | inhambane
# Processing Record 36 of Set 6 | val-david
# Processing Record 37 of Set 6 | san quintin
# Processing Record 38 of Set 6 | san-pedro
# Processing Record 39 of Set 6 | norman wells
# Processing Record 40 of Set 6 | lae
# Processing Record 41 of Set 6 | kupino
# Processing Record 42 of Set 6 | banes
# Processing Record 43 of Set 6 | redlands
# Processing Record 44 of Set 6 | goderich
# Processing Record 45 of Set 6 | richards bay
# Processing Record 46 of Set 6 | hyeres
# Processing Record 47 of Set 6 | mar del plata
# Processing Record 48 of Set 6 | hirara
# Processing Record 49 of Set 6 | hithadhoo
# Processing Record 50 of Set 6 | malakal
# Processing Record 1 of Set 7 | qaqortoq
# Processing Record 2 of Set 7 | tiksi
# Processing Record 3 of Set 7 | marsa matruh
# Processing Record 4 of Set 7 | pakwach
# City not found. Skipping...
# Processing Record 5 of Set 7 | peace river
# Processing Record 6 of Set 7 | bayir
# Processing Record 7 of Set 7 | adrar
# Processing Record 8 of Set 7 | skagen
# Processing Record 9 of Set 7 | lamu
# Processing Record 10 of Set 7 | touros
# Processing Record 11 of Set 7 | hamilton
# Processing Record 12 of Set 7 | anadyr
# Processing Record 13 of Set 7 | qeshm
# Processing Record 14 of Set 7 | acari
# Processing Record 15 of Set 7 | rondonopolis
# Processing Record 16 of Set 7 | sibolga
# Processing Record 17 of Set 7 | tarakan
# Processing Record 18 of Set 7 | faanui
# Processing Record 19 of Set 7 | rocha
# Processing Record 20 of Set 7 | sturgeon bay
# Processing Record 21 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 7 | brigantine
# Processing Record 23 of Set 7 | aguimes
# Processing Record 24 of Set 7 | nyurba
# Processing Record 25 of Set 7 | havre-saint-pierre
# Processing Record 26 of Set 7 | okhotsk
# Processing Record 27 of Set 7 | ambovombe
# Processing Record 28 of Set 7 | marsabit
# Processing Record 29 of Set 7 | la romana
# Processing Record 30 of Set 7 | pushkinskiye gory
# Processing Record 31 of Set 7 | port blair
# Processing Record 32 of Set 7 | sao sebastiao
# Processing Record 33 of Set 7 | elverum
# Processing Record 34 of Set 7 | donskoye
# Processing Record 35 of Set 7 | muros
# Processing Record 36 of Set 7 | pyshma
# Processing Record 37 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 7 | joshimath
# Processing Record 39 of Set 7 | izumo
# Processing Record 40 of Set 7 | bumba
# Processing Record 41 of Set 7 | pafos
# Processing Record 42 of Set 7 | abu kamal
# Processing Record 43 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 7 | cartagena
# Processing Record 45 of Set 7 | tome-acu
# City not found. Skipping...
# Processing Record 46 of Set 7 | phangnga
# Processing Record 47 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 7 | garden city
# Processing Record 49 of Set 7 | choucheng
# City not found. Skipping...
# Processing Record 50 of Set 7 | margate
# Processing Record 1 of Set 8 | clyde river
# Processing Record 2 of Set 8 | xicotencatl
# Processing Record 3 of Set 8 | boissevain
# Processing Record 4 of Set 8 | hokitika
# Processing Record 5 of Set 8 | hami
# Processing Record 6 of Set 8 | mackay
# Processing Record 7 of Set 8 | san francisco
# Processing Record 8 of Set 8 | lobito
# Processing Record 9 of Set 8 | avera
# Processing Record 10 of Set 8 | talcahuano
# Processing Record 11 of Set 8 | milkovo
# Processing Record 12 of Set 8 | marsh harbour
# Processing Record 13 of Set 8 | carnarvon
# Processing Record 14 of Set 8 | nouadhibou
# Processing Record 15 of Set 8 | meulaboh
# Processing Record 16 of Set 8 | sinnamary
# Processing Record 17 of Set 8 | frankenberg
# Processing Record 18 of Set 8 | whitefish
# Processing Record 19 of Set 8 | turtkul
# City not found. Skipping...
# Processing Record 20 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 8 | laguna
# Processing Record 22 of Set 8 | boundiali
# Processing Record 23 of Set 8 | yaan
# Processing Record 24 of Set 8 | bangassou
# Processing Record 25 of Set 8 | vestmannaeyjar
# Processing Record 26 of Set 8 | port hedland
# Processing Record 27 of Set 8 | sao filipe
# Processing Record 28 of Set 8 | punta alta
# Processing Record 29 of Set 8 | linda
# Processing Record 30 of Set 8 | lata
# Processing Record 31 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 8 | sobolevo
# Processing Record 33 of Set 8 | kemijarvi
# Processing Record 34 of Set 8 | mariental
# Processing Record 35 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 8 | sikonge
# Processing Record 37 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 8 | brownwood
# Processing Record 39 of Set 8 | pocone
# Processing Record 40 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 41 of Set 8 | porto torres
# Processing Record 42 of Set 8 | la palma
# Processing Record 43 of Set 8 | saravena
# Processing Record 44 of Set 8 | gorontalo
# Processing Record 45 of Set 8 | vasilyevskiy mokh
# Processing Record 46 of Set 8 | formosa
# Processing Record 47 of Set 8 | caravelas
# Processing Record 48 of Set 8 | northam
# Processing Record 49 of Set 8 | bani
# Processing Record 50 of Set 8 | mmabatho
# Processing Record 1 of Set 9 | bacolod
# Processing Record 2 of Set 9 | marsaxlokk
# Processing Record 3 of Set 9 | ayr
# Processing Record 4 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 9 | grande prairie
# Processing Record 8 of Set 9 | lavrentiya
# Processing Record 9 of Set 9 | lasa
# Processing Record 10 of Set 9 | waw
# Processing Record 11 of Set 9 | penarroya-pueblonuevo
# Processing Record 12 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 9 | palmer
# Processing Record 14 of Set 9 | sisimiut
# Processing Record 15 of Set 9 | san patricio
# Processing Record 16 of Set 9 | davila
# Processing Record 17 of Set 9 | yantzaza
# Processing Record 18 of Set 9 | dosso
# Processing Record 19 of Set 9 | flinders
# Processing Record 20 of Set 9 | sitka
# Processing Record 21 of Set 9 | kuytun
# Processing Record 22 of Set 9 | nisia floresta
# Processing Record 23 of Set 9 | balkhash
# Processing Record 24 of Set 9 | arcata
# Processing Record 25 of Set 9 | agnibilekrou
# Processing Record 26 of Set 9 | novaya ladoga
# Processing Record 27 of Set 9 | moose factory
# Processing Record 28 of Set 9 | nikolayevsk-na-amure
# Processing Record 29 of Set 9 | umm lajj
# Processing Record 30 of Set 9 | codrington
# Processing Record 31 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 32 of Set 9 | manta
# Processing Record 33 of Set 9 | fairbanks
# Processing Record 34 of Set 9 | sao felix do xingu
# Processing Record 35 of Set 9 | dolores
# Processing Record 36 of Set 9 | southbridge
# Processing Record 37 of Set 9 | padang
# Processing Record 38 of Set 9 | arona
# Processing Record 39 of Set 9 | roebourne
# Processing Record 40 of Set 9 | gat
# Processing Record 41 of Set 9 | obihiro
# Processing Record 42 of Set 9 | alugan
# Processing Record 43 of Set 9 | hede
# Processing Record 44 of Set 9 | panjab
# Processing Record 45 of Set 9 | klaksvik
# Processing Record 46 of Set 9 | grimshaw
# Processing Record 47 of Set 9 | malindi
# Processing Record 48 of Set 9 | abilene
# Processing Record 49 of Set 9 | montepuez
# Processing Record 50 of Set 9 | wiarton
# Processing Record 1 of Set 10 | borovoy
# Processing Record 2 of Set 10 | broome
# Processing Record 3 of Set 10 | tiznit
# Processing Record 4 of Set 10 | ulagan
# Processing Record 5 of Set 10 | kismayo
# Processing Record 6 of Set 10 | dunedin
# Processing Record 7 of Set 10 | mahaicony
# City not found. Skipping...
# Processing Record 8 of Set 10 | murgab
# Processing Record 9 of Set 10 | antofagasta
# Processing Record 10 of Set 10 | tatawin
# Processing Record 11 of Set 10 | glubokoe
# City not found. Skipping...
# Processing Record 12 of Set 10 | wawa
# Processing Record 13 of Set 10 | rawson
# Processing Record 14 of Set 10 | puerto asis
# Processing Record 15 of Set 10 | chiman
# Processing Record 16 of Set 10 | poya
# Processing Record 17 of Set 10 | praia da vitoria
# Processing Record 18 of Set 10 | wagar
# Processing Record 19 of Set 10 | artesia
# Processing Record 20 of Set 10 | gambela
# Processing Record 21 of Set 10 | kedrovyy
# Processing Record 22 of Set 10 | chandbali
# Processing Record 23 of Set 10 | sidney
# Processing Record 24 of Set 10 | north platte
# Processing Record 25 of Set 10 | buin
# Processing Record 26 of Set 10 | morgan city
# Processing Record 27 of Set 10 | chiredzi
# Processing Record 28 of Set 10 | kurchum
# Processing Record 29 of Set 10 | maceio
# Processing Record 30 of Set 10 | lampazos de naranjo
# Processing Record 31 of Set 10 | sunrise manor
# Processing Record 32 of Set 10 | berlevag
# Processing Record 33 of Set 10 | riyadh
# Processing Record 34 of Set 10 | rabaul
# Processing Record 35 of Set 10 | inzer
# Processing Record 36 of Set 10 | keti bandar
# Processing Record 37 of Set 10 | constitucion
# Processing Record 38 of Set 10 | sao raimundo das mangabeiras
# Processing Record 39 of Set 10 | beringovskiy
# Processing Record 40 of Set 10 | prainha
# Processing Record 41 of Set 10 | saint peter
# Processing Record 42 of Set 10 | abiy adi
# City not found. Skipping...
# Processing Record 43 of Set 10 | carevo
# City not found. Skipping...
# Processing Record 44 of Set 10 | tura
# Processing Record 45 of Set 10 | kisangani
# Processing Record 46 of Set 10 | olinda
# Processing Record 47 of Set 10 | puerto penasco
# Processing Record 48 of Set 10 | manavalakurichi
# Processing Record 49 of Set 10 | nokaneng
# Processing Record 50 of Set 10 | rio gallegos
# Processing Record 1 of Set 11 | port hardy
# Processing Record 2 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 11 | kirovskiy
# Processing Record 4 of Set 11 | andapa
# Processing Record 5 of Set 11 | pangnirtung
# Processing Record 6 of Set 11 | honiara
# Processing Record 7 of Set 11 | valley city
# Processing Record 8 of Set 11 | amboasary
# Processing Record 9 of Set 11 | askoy
# Processing Record 10 of Set 11 | necochea
# Processing Record 11 of Set 11 | round rock
# Processing Record 12 of Set 11 | alikovo
# Processing Record 13 of Set 11 | kousseri
# Processing Record 14 of Set 11 | pangody
# Processing Record 15 of Set 11 | mitzic
# Processing Record 16 of Set 11 | carlisle
# Processing Record 17 of Set 11 | sayat
# Processing Record 18 of Set 11 | morristown
# Processing Record 19 of Set 11 | vilhena

# %%
len(city_data)

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
new_column_order =["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
